# %%
# %load datasvc.py
import httpx
import pandas
from .util import format_dates


BLOCKARRIVE_BASISCODE = {
    -6: "no_source",
    -5: "no_link",
    -4: "auto_suspend",
    -3: "no_download_link",
    -2: "manual_suspend",
    -1: "block_open",
    0: "routed",
    1: "queue_full",
    2: "rerouting",
}


class DataSvc:
    """PhEDEx datasvc REST API

    Full documentation at https://cmsweb.cern.ch/phedex/datasvc/doc
    """

    defaults = {
        # PhEDEx datasvc base URL with trailing slash
        "datasvc_base": "https://cmsweb.cern.ch/phedex/datasvc/",
        # Options: prod, dev, debug
        "phedex_instance": "prod",
    }

    def __init__(self, client, datasvc_base=None, phedex_instance=None):
        if datasvc_base is None:
            datasvc_base = DataSvc.defaults["datasvc_base"]
        if phedex_instance is None:
            phedex_instance = DataSvc.defaults["phedex_instance"]
        self.client = client
        self.baseurl = httpx.URL(datasvc_base)
        self.jsonurl = self.baseurl.join("json/%s/" % phedex_instance)
        self.xmlurl = self.baseurl.join("xml/%s/" % phedex_instance)

    async def jsonmethod(self, method, **params):
        return await self.client.getjson(url=self.jsonurl.join(method), params=params)

    async def blockreplicas(self, **params):
        """Get block replicas as a pandas dataframe

        Parameters
        ----------
        block          block name, can be multiple (*)
        dataset        dataset name, can be multiple (*)
        node           node name, can be multiple (*)
        se             storage element name, can be multiple (*)
        update_since   unix timestamp, only return replicas whose record was
                        updated since this time
        create_since   unix timestamp, only return replicas whose record was
                        created since this time. When no "dataset", "block"
                        or "node" are given, create_since is default to 24 hours ago
        complete       y or n, whether or not to require complete or incomplete
                        blocks. Open blocks cannot be complete.  Default is to
                        return either.
        dist_complete  y or n, "distributed complete".  If y, then returns
                        only block replicas for which at least one node has
                        all files in the block.  If n, then returns block
                        replicas for which no node has all the files in the
                        block.  Open blocks cannot be dist_complete.  Default is
                        to return either kind of block replica.
        subscribed     y or n, filter for subscription. default is to return either.
        custodial      y or n. filter for custodial responsibility.  default is
                        to return either.
        group          group name.  default is to return replicas for any group.
        show_dataset   y or n, default n. If y, show dataset information with
                        the blocks; if n, only show blocks
        """
        resjson = await self.jsonmethod("blockreplicas", **params)
        df = pandas.io.json.json_normalize(
            resjson["phedex"]["block"],
            record_path="replica",
            record_prefix="replica.",
            meta=["bytes", "files", "name", "id", "is_open"],
        )
        format_dates(df, ["replica.time_create", "replica.time_update"])
        return df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-119-3f23eca94c38> in <module>
#       1 # %load datasvc.py
# ----> 2 import httpx
#       3 import pandas
#       4 from .util import format_dates
#       5
#
# ModuleNotFoundError: No module named 'httpx'

# %%
# %load util.py
import pandas
import json

def format_dates(df, columns):
    """Convert UNIX timestamp columns to datetime"""
    if df.size > 0:
        df[columns] = df[columns].apply(lambda v: pandas.to_datetime(v, unit="s"))
    return df

# %%
with open('data_method_test.json') as f:
    data = json.load(f)

# %%
#Data_Method

async def data(self, **params):
    
        """Shows data which is registered (injected) to phedex
        
        Parameters
        ----------
        
        dataset                  dataset name to output data for (wildcard support)
        block                    block name to output data for (wildcard support)
        file                     file name to output data for (wildcard support)
        level                    display level, 'file' or 'block'. when level=block
                                 no file details would be shown. Default is 'file'.
                                 when level = 'block', return data of which blocks were created since this time;
                                 when level = 'file', return data of which files were created since this time
        create_since             when no parameters are given, default create_since is set to one day ago
        """
        resjson = await self.jsonmethod("data", **params)
        df = pandas.io.json.json_normalize(
            rejson['phedex']['dbs']['dataset'],
            )

# %%
data
# Out:
# {'phedex': {'request_timestamp': 1584563680.53556,
#   'dbs': [{'dataset': [{'time_update': None,
#       'is_transient': 'n',
#       'is_open': 'y',
#       'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO',
#       'block': [{'time_update': 1574197309.67013,
#         'bytes': 2353710973,
#         'files': 3,
#         'file': [{'checksum': 'adler32:84458e13,cksum:843148796',
#           'node': 'T2_FR_GRIF_IRFU',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/EE179485-B1C5-7249-A077-3D133C0198EB.root',
#           'time_create': 1574024907.65851,
#           'size': 569420538},
#          {'checksum': 'adler32:d290b9c8,cksum:4293630207',
#           'node': 'T2_FR_GRIF_IRFU',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/81217908-BEC2-E84C-ACDC-8132B48A4A25.root',
#           'time_create': 1574197074.00792,
#           'size': 1406279668},
#          {'checksum': 'adler32:b4fddac3,cksum:4218643856',
#           'node': 'T2_FR_GRIF_IRFU',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/84F00E72-D075-BF46-B8DE-FB4A7C0B4535.root',
#           'time_create': 1574110773.4523,
#           'size': 378010767}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#2f9cf305-991b-449a-903e-c452dfd1c782',
#         'is_open': 'n',
#         'time_create': 1574024907.65851},
#        {'time_update': 1574282778.21919,
#         'bytes': 1812333230,
#         'files': 3,
#         'file': [{'checksum': 'adler32:d273d7ef,cksum:2120672845',
#           'node': 'T2_US_Nebraska',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/E53B9F5C-DEBF-2641-BE5B-5CB7173122D9.root',
#           'time_create': 1574110458.04684,
#           'size': 1440351579},
#          {'checksum': 'adler32:e92fd24e,cksum:1545795842',
#           'node': 'T2_US_Nebraska',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/0568A9F6-0E46-324D-BD0C-ACE469BC1F99.root',
#           'time_create': 1574181882.15846,
#           'size': 313277819},
#          {'checksum': 'adler32:71e35f71,cksum:808729787',
#           'node': 'T2_US_Nebraska',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/A9B3CB04-F540-C749-9E05-313309270668.root',
#           'time_create': 1574266230.70779,
#           'size': 58703832}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#eb8942af-59a0-4914-a1f0-899850f54f16',
#         'is_open': 'n',
#         'time_create': 1574110458.04684},
#        {'time_update': 1575700753.75806,
#         'bytes': 273975362,
#         'files': 1,
#         'file': [{'checksum': 'adler32:a95c43a4,cksum:968438290',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/EEA43F03-DBE3-EE45-9518-6B6AAFDC516D.root',
#           'time_create': 1575527941.5283,
#           'size': 273975362}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#73bcd020-4845-4229-b605-8310c07e8177',
#         'is_open': 'n',
#         'time_create': 1575527941.5283},
#        {'time_update': 1574465167.65366,
#         'bytes': 144513249,
#         'files': 3,
#         'file': [{'checksum': 'adler32:29e5cdbf,cksum:2423106562',
#           'node': 'T1_DE_KIT_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/02D73CAB-886B-C541-AE59-B680647183E3.root',
#           'time_create': 1574292613.84988,
#           'size': 34620033},
#          {'checksum': 'adler32:04474323,cksum:605316214',
#           'node': 'T1_DE_KIT_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/FB2872E4-E883-B74B-B4FA-B057CEB1B406.root',
#           'time_create': 1574327680.744,
#           'size': 50926179},
#          {'checksum': 'adler32:55827179,cksum:2645865792',
#           'node': 'T1_DE_KIT_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/ABEAFB90-0EB3-8F4E-B044-6DF63EB2A1DD.root',
#           'time_create': 1574431755.9483,
#           'size': 58967037}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#cf521ff3-6d7a-48e9-b43f-e9902d628aec',
#         'is_open': 'n',
#         'time_create': 1574292613.84988},
#        {'time_update': 1574250717.88752,
#         'bytes': 8498415985,
#         'files': 6,
#         'file': [{'checksum': 'adler32:79a012fa,cksum:3476130357',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/ABC06364-0BFD-F14E-A8D7-DB114EFF5B0D.root',
#           'time_create': 1574123518.41757,
#           'size': 720739127},
#          {'checksum': 'adler32:58347f62,cksum:3560414439',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/3FA8B098-D622-354C-9564-3C92C12CFD20.root',
#           'time_create': 1574148550.60053,
#           'size': 1648470454},
#          {'checksum': 'adler32:6158e8e3,cksum:1096262133',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/035DD498-02C4-6848-A836-CD5D221D9ABE.root',
#           'time_create': 1574179528.28446,
#           'size': 1760479355},
#          {'checksum': 'adler32:2e0256e5,cksum:3604762707',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/A8D4296B-AF8C-AC42-BDF9-2C8B5137B5C4.root',
#           'time_create': 1574077586.2543,
#           'size': 954239411},
#          {'checksum': 'adler32:3dbf8c59,cksum:748099289',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/79DA0D6E-096D-F142-8015-0FE43FD70003.root',
#           'time_create': 1574137064.04349,
#           'size': 1726549862},
#          {'checksum': 'adler32:2ec3b80a,cksum:3421510219',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/E23BBF6B-CB94-484E-96A7-E2E8B524099E.root',
#           'time_create': 1574161552.12742,
#           'size': 1687937776}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#041f8cf2-c800-466f-b50e-ee15f5259db4',
#         'is_open': 'n',
#         'time_create': 1574077586.2543},
#        {'time_update': 1574221609.50586,
#         'bytes': 12921640720,
#         'files': 8,
#         'file': [{'checksum': 'adler32:7182c320,cksum:3123184743',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/B8831F82-7DDD-5742-9BCD-D0515999D86F.root',
#           'time_create': 1574164468.57116,
#           'size': 1705037598},
#          {'checksum': 'adler32:b4faeedd,cksum:2953794691',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6EFA3059-EE68-0343-AF37-6F4AF8E061AD.root',
#           'time_create': 1574147738.57789,
#           'size': 1797871256},
#          {'checksum': 'adler32:5bfb5420,cksum:716815821',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/401DF669-62AF-AC4D-9428-6552F72D39A3.root',
#           'time_create': 1574048840.27256,
#           'size': 586054118},
#          {'checksum': 'adler32:8c2bf100,cksum:3420361146',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/30C0789C-1ED0-1745-B690-E9248B8E78E8.root',
#           'time_create': 1574156705.99583,
#           'size': 1720285984},
#          {'checksum': 'adler32:421c65a4,cksum:3167447357',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/E18CC159-748C-E643-A9CA-CF822C5DA688.root',
#           'time_create': 1574141010.10734,
#           'size': 1918169282},
#          {'checksum': 'adler32:d11cd344,cksum:2110758565',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/CF23812A-DDA6-A742-82F9-B793CCE97B55.root',
#           'time_create': 1574179571.92267,
#           'size': 1784159122},
#          {'checksum': 'adler32:4c7bd511,cksum:2437957416',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/AA191AE7-A837-F448-B898-DA828AC4CD62.root',
#           'time_create': 1574206816.28901,
#           'size': 1795843710},
#          {'checksum': 'adler32:0db75fe0,cksum:2537145858',
#           'node': 'T1_UK_RAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/9C7ABAF6-14DC-8649-A6E5-059B529660BC.root',
#           'time_create': 1574131176.57211,
#           'size': 1614219650}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#8f13d583-df04-46b8-8e44-03dca0f4eb46',
#         'is_open': 'n',
#         'time_create': 1574048840.27256},
#        {'time_update': 1574333358.20878,
#         'bytes': 1787288769,
#         'files': 2,
#         'file': [{'checksum': 'adler32:0d0161e7,cksum:1525632411',
#           'node': 'T2_DE_DESY',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/D827322D-02DE-1A4D-A03A-FEA76671A733.root',
#           'time_create': 1574160131.5945,
#           'size': 473678656},
#          {'checksum': 'adler32:c5ba45e2,cksum:2160197365',
#           'node': 'T2_DE_DESY',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/8A7E172E-B6AB-0546-BC0E-A891427E7051.root',
#           'time_create': 1574329955.70623,
#           'size': 1313610113}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#7da7dc8f-2d73-49b8-8058-d9bd23cc3c7c',
#         'is_open': 'n',
#         'time_create': 1574160131.5945},
#        {'time_update': 1574529732.72428,
#         'bytes': 1772958009,
#         'files': 2,
#         'file': [{'checksum': 'adler32:b9dd25ed,cksum:4196122122',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/26601263-F537-8546-AB59-523733861332.root',
#           'time_create': 1574446311.00489,
#           'size': 382992077},
#          {'checksum': 'adler32:84b5a078,cksum:1575745274',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/A2E400F3-D5AF-D54F-AC22-EC496D96DF99.root',
#           'time_create': 1574356787.61098,
#           'size': 1389965932}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#7a66fa46-2f0f-4077-a437-5e517a6df879',
#         'is_open': 'n',
#         'time_create': 1574356787.61098},
#        {'time_update': 1574396341.51659,
#         'bytes': 4795131116,
#         'files': 3,
#         'file': [{'checksum': 'adler32:335300c8,cksum:1233093466',
#           'node': 'T1_ES_PIC_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/DEE9FB11-3C0E-114A-9634-E3806F252EEA.root',
#           'time_create': 1574223671.51869,
#           'size': 1779268874},
#          {'checksum': 'adler32:17d06401,cksum:3237401152',
#           'node': 'T1_ES_PIC_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/D1A17E86-DBF7-CB43-9774-CC0C0F4D6C9B.root',
#           'time_create': 1574339852.66815,
#           'size': 1405454798},
#          {'checksum': 'adler32:4862e05a,cksum:2395800153',
#           'node': 'T1_ES_PIC_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/DF17DEFE-C8F0-2748-96AB-82EC248DAD8E.root',
#           'time_create': 1574253936.22735,
#           'size': 1610407444}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#865683a2-608a-4a17-b677-c757b4088078',
#         'is_open': 'n',
#         'time_create': 1574223671.51869},
#        {'time_update': 1574485807.65721,
#         'bytes': 28193380988,
#         'files': 13,
#         'file': [{'checksum': 'adler32:4d884666,cksum:472049215',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/36CB7A7B-3E4C-844B-95B1-22F312C4EF8D.root',
#           'time_create': 1574343993.25438,
#           'size': 1534679991},
#          {'checksum': 'adler32:44daf2fd,cksum:3881313563',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/8EF9DB4A-AD46-EF42-86D9-72F8FBABE317.root',
#           'time_create': 1574393027.06267,
#           'size': 2142686850},
#          {'checksum': 'adler32:ca3252e2,cksum:265204541',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/EBAEEF7B-193A-014D-8027-CD85C0314BE6.root',
#           'time_create': 1574313259.04271,
#           'size': 1478483522},
#          {'checksum': 'adler32:57080e5c,cksum:1166024632',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/660B7DE9-B032-F942-9624-501CBA37D6FF.root',
#           'time_create': 1574478868.2523,
#           'size': 2590257061},
#          {'checksum': 'adler32:6193d884,cksum:3352499354',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/1F147A0E-1323-A945-BA5D-598C7CB51AE4.root',
#           'time_create': 1574407191.80319,
#           'size': 2688784664},
#          {'checksum': 'adler32:4445fa89,cksum:1597212907',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/C0579669-7FEE-6447-A8E1-94544A853550.root',
#           'time_create': 1574452307.57989,
#           'size': 2377346515},
#          {'checksum': 'adler32:089307a1,cksum:3819212974',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/6A2B677D-C362-924F-B0AC-EC6AC8A20862.root',
#           'time_create': 1574465591.28613,
#           'size': 2163313752},
#          {'checksum': 'adler32:6dcdc79b,cksum:1442911958',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/BFABFC24-40E1-4147-81A6-C3F7D55C9419.root',
#           'time_create': 1574386682.94343,
#           'size': 2027107037},
#          {'checksum': 'adler32:0625f4de,cksum:1076110459',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/5F5564BC-39D4-7B4D-A3C2-BBCF27FDA4D5.root',
#           'time_create': 1574484112.26352,
#           'size': 2840223029},
#          {'checksum': 'adler32:d17ca64b,cksum:3652933190',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/CCFDB354-7CD0-2B46-9F62-364336AF4414.root',
#           'time_create': 1574472709.27903,
#           'size': 2385689548},
#          {'checksum': 'adler32:00c17305,cksum:2655783054',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/ECE7FE48-F5BB-E446-BF50-35D9F9C0807B.root',
#           'time_create': 1574369504.14403,
#           'size': 1979650518},
#          {'checksum': 'adler32:52ef4ef0,cksum:1243660677',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/65B03109-1092-C340-ACD9-B9745DD14824.root',
#           'time_create': 1574358656.31287,
#           'size': 1981476016},
#          {'checksum': 'adler32:f8dabb8a,cksum:3934157316',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/4D84DE24-08E5-2844-BA56-70C2A1A51BD4.root',
#           'time_create': 1574399992.01433,
#           'size': 2003682485}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#1076d468-1811-4064-95db-92f151cd614a',
#         'is_open': 'n',
#         'time_create': 1574313259.04271},
#        {'time_update': 1574293059.4929,
#         'bytes': 237869363,
#         'files': 1,
#         'file': [{'checksum': 'adler32:6ef5d259,cksum:1345480614',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/32C371D4-685B-1444-86D2-A2FF2BEDBFD6.root',
#           'time_create': 1574120315.3962,
#           'size': 237869363}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#f3801e84-df85-4d03-a9cd-f22482d50486',
#         'is_open': 'n',
#         'time_create': 1574120315.3962},
#        {'time_update': 1574426683.21502,
#         'bytes': 1576430660,
#         'files': 2,
#         'file': [{'checksum': 'adler32:16f8b44b,cksum:666146412',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/F392C78A-28F2-FF49-85C8-7301EB598DBD.root',
#           'time_create': 1574254160.56819,
#           'size': 1370844781},
#          {'checksum': 'adler32:8ae54be5,cksum:3354155197',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/213721DF-76EC-8D4A-A7B2-3551939EC51B.root',
#           'time_create': 1574339412.23658,
#           'size': 205585879}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#e24fc48d-1cad-4c2a-a3f6-2d9033d0297d',
#         'is_open': 'n',
#         'time_create': 1574254160.56819},
#        {'time_update': 1574279840.15553,
#         'bytes': 7288335320,
#         'files': 5,
#         'file': [{'checksum': 'adler32:44485f26,cksum:787129580',
#           'node': 'T2_BE_UCL',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/F2C594F1-1ED4-A94C-9ED2-4820A17F144C.root',
#           'time_create': 1574163607.34225,
#           'size': 1565785033},
#          {'checksum': 'adler32:f6473fe1,cksum:3750176148',
#           'node': 'T2_BE_UCL',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/F804F159-563A-7342-B5FF-EFD51E95E6C4.root',
#           'time_create': 1574107171.65425,
#           'size': 1572587206},
#          {'checksum': 'adler32:b17490c2,cksum:347765751',
#           'node': 'T2_BE_UCL',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/BE26E863-E3E8-6E49-82E8-0F4D48CB625C.root',
#           'time_create': 1574146946.13484,
#           'size': 1541401891},
#          {'checksum': 'adler32:b0aad4a5,cksum:143795118',
#           'node': 'T2_BE_UCL',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/5A1B00F7-0BA3-E748-8C98-C360EAC1593B.root',
#           'time_create': 1574248787.6194,
#           'size': 1173481048},
#          {'checksum': 'adler32:2c20553d,cksum:382724159',
#           'node': 'T2_BE_UCL',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/83F766DC-C1B4-C943-A1F8-72FFA93BBCB2.root',
#           'time_create': 1574126945.76627,
#           'size': 1435080142}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#0d67a73c-c446-4902-a977-db8500c63924',
#         'is_open': 'n',
#         'time_create': 1574107171.65425},
#        {'time_update': 1574170817.04611,
#         'bytes': 16329462924,
#         'files': 10,
#         'file': [{'checksum': 'adler32:72ada5d4,cksum:1147817405',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/DBDF022C-7CD4-F643-B9B1-D93C8ABC79C3.root',
#           'time_create': 1574112821.74565,
#           'size': 1420690600},
#          {'checksum': 'adler32:f079264f,cksum:3626489056',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/F013D66C-6601-A846-88F0-6C1BEC72459B.root',
#           'time_create': 1574053477.11111,
#           'size': 1689917321},
#          {'checksum': 'adler32:1290a663,cksum:4197696726',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/4B374515-2749-0441-8FD5-53C7FDF1C3B6.root',
#           'time_create': 1574128913.93218,
#           'size': 1694725244},
#          {'checksum': 'adler32:5e832fd9,cksum:692802192',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6B904AC0-3C95-314C-BC57-0DC24F2502B8.root',
#           'time_create': 1574077884.90396,
#           'size': 1640922307},
#          {'checksum': 'adler32:afec96f2,cksum:1892024568',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/835725C5-27EA-9F4A-B50A-6BC033B28364.root',
#           'time_create': 1573997103.10874,
#           'size': 1547194673},
#          {'checksum': 'adler32:1014c7ae,cksum:2133384419',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/7BF07B1E-BF19-C94D-8126-89F14A8B4CD2.root',
#           'time_create': 1574067514.6131,
#           'size': 1712981171},
#          {'checksum': 'adler32:e6b167c1,cksum:2168947916',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/944D4AD9-87E1-604E-A720-B4EF15BBA935.root',
#           'time_create': 1574037615.10297,
#           'size': 1625366393},
#          {'checksum': 'adler32:89ce0b8a,cksum:3985931860',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6F16D34B-D20A-904A-9061-3FA9588CF1A7.root',
#           'time_create': 1574168379.84163,
#           'size': 1620862225},
#          {'checksum': 'adler32:ffecd2ef,cksum:3000461026',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/7BECCB55-DC0C-474F-AE17-EB8BCA5BD658.root',
#           'time_create': 1574150442.28895,
#           'size': 1815975263},
#          {'checksum': 'adler32:aa3e3ff2,cksum:3653851234',
#           'node': 'T2_UK_London_Brunel',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/C2658F50-FD58-2644-A08F-07B12FFD8F5E.root',
#           'time_create': 1574015465.44084,
#           'size': 1560827727}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#023aae4f-26a7-44cb-bf14-d41dace0b00b',
#         'is_open': 'n',
#         'time_create': 1573997103.10874},
#        {'time_update': 1575291095.76432,
#         'bytes': 1041147163,
#         'files': 2,
#         'file': [{'checksum': 'adler32:68548b2e,cksum:4217150509',
#           'node': 'T2_IT_Legnaro',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/21164EBE-8BCA-9F4D-81A4-D0BC794033BB.root',
#           'time_create': 1575221929.61277,
#           'size': 86180044},
#          {'checksum': 'adler32:7a844221,cksum:1475267775',
#           'node': 'T2_IT_Legnaro',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/A57E467A-C630-544F-9020-D9B9A8BEBA26.root',
#           'time_create': 1575130835.48924,
#           'size': 954967119}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#92ef5b35-d734-4679-b037-f4d9e5689888',
#         'is_open': 'n',
#         'time_create': 1575130835.48924},
#        {'time_update': 1575593663.53823,
#         'bytes': 88889008947,
#         'files': 51,
#         'file': [{'checksum': 'adler32:2c626155,cksum:1851421881',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/F6DA294F-97AC-1A4A-8F3D-60D6DBA45FE6.root',
#           'time_create': 1575438676.71393,
#           'size': 2182780687},
#          {'checksum': 'adler32:fdf26b83,cksum:2229963082',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/096B92F0-C382-514E-A19A-3F605B1F1302.root',
#           'time_create': 1575469448.66459,
#           'size': 1866969612},
#          {'checksum': 'adler32:a2f26572,cksum:965755252',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/DAFA402F-327A-074A-9B38-787720511F97.root',
#           'time_create': 1575526268.88209,
#           'size': 1541942954},
#          {'checksum': 'adler32:e716dae2,cksum:2673306810',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/2BC7F884-6175-8F4D-932A-9328AB417B58.root',
#           'time_create': 1575459777.53166,
#           'size': 1793566679},
#          {'checksum': 'adler32:f6aee3ca,cksum:4134544278',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/C0C1DA7E-91C0-EE4B-8289-8468198D6235.root',
#           'time_create': 1575483042.67297,
#           'size': 1751654745},
#          {'checksum': 'adler32:bec59747,cksum:1410273729',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/A46DE919-FF65-D64D-9918-BEBA6F112DE2.root',
#           'time_create': 1575451826.54984,
#           'size': 1694271758},
#          {'checksum': 'adler32:e3cb0662,cksum:3985778885',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/68006CF1-09C8-D349-9F1D-0DD82A4A97B9.root',
#           'time_create': 1575473698.21503,
#           'size': 1991007362},
#          {'checksum': 'adler32:f473e60a,cksum:4138260407',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/A8D629DD-CD21-904B-BA74-6FB44786E31D.root',
#           'time_create': 1575534770.87237,
#           'size': 1510179382},
#          {'checksum': 'adler32:28669a83,cksum:2086690455',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/92FC740A-4109-8A4F-A877-4076D0F35931.root',
#           'time_create': 1575538905.25256,
#           'size': 1646701646},
#          {'checksum': 'adler32:4bcc131f,cksum:2560208519',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/85A10693-6FEB-224B-9B3D-2F50DD956E8C.root',
#           'time_create': 1575521034.91825,
#           'size': 1763372743},
#          {'checksum': 'adler32:b55201ac,cksum:121009708',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/9B93D240-D84C-4D4B-A3DC-9C0B564428FB.root',
#           'time_create': 1575490204.8255,
#           'size': 1796039331},
#          {'checksum': 'adler32:f88481aa,cksum:1032447077',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/631B7110-F47C-4E4D-A74C-7305797357C7.root',
#           'time_create': 1575553137.67229,
#           'size': 1657040047},
#          {'checksum': 'adler32:2c2c1e02,cksum:211201097',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/E9A78EB2-B27C-5D49-A970-15B71D091435.root',
#           'time_create': 1575433599.71631,
#           'size': 1707846068},
#          {'checksum': 'adler32:1a6567f6,cksum:702624590',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/CF5D2784-8FDE-5D48-B26D-13A86F814657.root',
#           'time_create': 1575501964.81708,
#           'size': 1921889159},
#          {'checksum': 'adler32:d961fb14,cksum:2151465913',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/ABA6B79B-CED5-974A-A99E-C02B1FB18E22.root',
#           'time_create': 1575464646.50092,
#           'size': 1695004088},
#          {'checksum': 'adler32:d3e791b3,cksum:1561361170',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/0C56970F-9736-8343-BA52-BE85F2D2BF8B.root',
#           'time_create': 1575422758.51035,
#           'size': 1579565706},
#          {'checksum': 'adler32:ed2603bb,cksum:3051505839',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/649DFDB8-2897-AA46-9398-0BD92E130BCA.root',
#           'time_create': 1575428051.41751,
#           'size': 1671918328},
#          {'checksum': 'adler32:a9f6d384,cksum:4202816641',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/E322F65F-0233-8C44-8B90-4752DCA81025.root',
#           'time_create': 1575510462.49725,
#           'size': 1710693405},
#          {'checksum': 'adler32:5546899c,cksum:2904663815',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/481A1A34-789B-FE49-B9EA-D9BF02F8A8C6.root',
#           'time_create': 1575475178.73176,
#           'size': 1828610111},
#          {'checksum': 'adler32:48193779,cksum:765853087',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/1B88833F-5EF4-EA49-A5E5-21176ED6D58B.root',
#           'time_create': 1575430158.24325,
#           'size': 1720154685},
#          {'checksum': 'adler32:a8c4727c,cksum:2994498997',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/FF99F1CB-5A95-954B-A1DE-DC1A7C42DA7E.root',
#           'time_create': 1575476868.86015,
#           'size': 1806532606},
#          {'checksum': 'adler32:f9fceecf,cksum:1623448796',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/3C188344-A1EA-FC42-A6FF-443D72A7949E.root',
#           'time_create': 1575449651.31591,
#           'size': 1847799270},
#          {'checksum': 'adler32:e3621705,cksum:1527655218',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/DFD7D979-8639-2F4A-B253-CD0BED0A9631.root',
#           'time_create': 1575420663.68625,
#           'size': 1341334925},
#          {'checksum': 'adler32:0cf26169,cksum:2628387877',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/8F222E2D-E496-914F-83CE-645FEAB3F4FE.root',
#           'time_create': 1575441039.28945,
#           'size': 1716952924},
#          {'checksum': 'adler32:83cce5ce,cksum:2515954653',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/1E0CA00D-261C-864D-A5DC-E1DC9C5265F9.root',
#           'time_create': 1575492824.423,
#           'size': 1782397365},
#          {'checksum': 'adler32:7bc8d0eb,cksum:716858973',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/5C4254E9-0C7B-6C48-A0BD-264255443EA1.root',
#           'time_create': 1575481833.01836,
#           'size': 1754810822},
#          {'checksum': 'adler32:1bd13100,cksum:1144877115',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/84D719EB-6C40-D24B-983B-819820CEC325.root',
#           'time_create': 1575426150.62853,
#           'size': 1656593766},
#          {'checksum': 'adler32:f6488689,cksum:1733761890',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/828C2174-E3C5-184F-BBF5-BD4CFCC44D38.root',
#           'time_create': 1575444244.77354,
#           'size': 1676200217},
#          {'checksum': 'adler32:dce78c1f,cksum:3429144553',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/8E189DB9-B23D-824D-A13A-756677AE7D31.root',
#           'time_create': 1575466609.43468,
#           'size': 1847342590},
#          {'checksum': 'adler32:ba5ac0b3,cksum:3089642444',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/AB324A00-BB9D-6448-8A66-CA57C804745E.root',
#           'time_create': 1575454186.87542,
#           'size': 1650473580},
#          {'checksum': 'adler32:facd26b2,cksum:4170961137',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/3F495D55-0EC3-4141-8AD3-B95EF1D09D9E.root',
#           'time_create': 1575456912.91441,
#           'size': 1630897457},
#          {'checksum': 'adler32:0ffd7b92,cksum:2136110723',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/B6AF5457-E497-344F-9BE7-B9E50A7B697A.root',
#           'time_create': 1575479475.26875,
#           'size': 2143341405},
#          {'checksum': 'adler32:2eda5809,cksum:537037293',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/C65AB9A8-7666-4340-97BA-320625FEED21.root',
#           'time_create': 1575435476.24718,
#           'size': 1977574705},
#          {'checksum': 'adler32:554e026d,cksum:2769002013',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/67288696-7909-A241-A97E-0359694DA302.root',
#           'time_create': 1575485489.88188,
#           'size': 2007926901},
#          {'checksum': 'adler32:86dd7d77,cksum:1368833740',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/9128B246-3967-AB4E-B76C-2629B987B4C3.root',
#           'time_create': 1575518317.48623,
#           'size': 1746417487},
#          {'checksum': 'adler32:ce23bf5e,cksum:1086280025',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/963ACAF7-E812-F940-A3E5-E9268148EB83.root',
#           'time_create': 1575425818.09239,
#           'size': 1930958946},
#          {'checksum': 'adler32:09bb4bd6,cksum:1870579011',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/E170C428-6A3A-9C42-A1C2-6BBF3F607A7C.root',
#           'time_create': 1575530329.31947,
#           'size': 1723999551},
#          {'checksum': 'adler32:1bd3b501,cksum:4103785245',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/96384D98-A470-1041-BE15-F7C1F06BB191.root',
#           'time_create': 1575485896.18467,
#           'size': 2056383025},
#          {'checksum': 'adler32:f7ab3842,cksum:1006098191',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/618AB5A3-7314-5F43-A505-78778847C5B9.root',
#           'time_create': 1575431678.44588,
#           'size': 1688630627},
#          {'checksum': 'adler32:4924ad3d,cksum:2150467924',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/8A74D9D6-E7AE-274C-8DB4-4B9E91C4CF9F.root',
#           'time_create': 1575564254.85342,
#           'size': 1431704933},
#          {'checksum': 'adler32:b8dfa2da,cksum:2359899423',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/EEA818CD-01AE-BC41-AE23-134ED4698E73.root',
#           'time_create': 1575505650.22292,
#           'size': 1758079444},
#          {'checksum': 'adler32:5828ae26,cksum:3314583986',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/79D02973-A800-624D-ADF4-AB3396D0D1F7.root',
#           'time_create': 1575423268.36977,
#           'size': 1543989765},
#          {'checksum': 'adler32:397485c3,cksum:711069179',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/9EDEBE7F-FFA3-5C42-8BAC-6316536F0F23.root',
#           'time_create': 1575462085.2855,
#           'size': 1698275914},
#          {'checksum': 'adler32:4ba9d2f6,cksum:4079289985',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/6A37A8A5-799B-514E-9ADD-64E6468ED45A.root',
#           'time_create': 1575496402.00658,
#           'size': 2039512872},
#          {'checksum': 'adler32:3d906bfb,cksum:1002362543',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/51D97A8F-B2A3-394B-A403-0CF1AC3E75CA.root',
#           'time_create': 1575557246.77506,
#           'size': 1457802919},
#          {'checksum': 'adler32:0e62d487,cksum:2126276449',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/FA8EC443-6FC5-8D4A-AD5D-88DBF6338D71.root',
#           'time_create': 1575548317.29662,
#           'size': 1585677234},
#          {'checksum': 'adler32:d08adbbf,cksum:1476509151',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/0A723754-3CBF-2F49-813B-B5F9750C66F1.root',
#           'time_create': 1575544158.26887,
#           'size': 1506435556},
#          {'checksum': 'adler32:a83ac7c3,cksum:2804617431',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/1B282D0D-1071-C84A-B944-CF523BA5CD98.root',
#           'time_create': 1575514368.8269,
#           'size': 1588156271},
#          {'checksum': 'adler32:81cc932a,cksum:898361406',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/01DD4F97-8F42-A747-9DCC-8C2E895644BE.root',
#           'time_create': 1575471565.37426,
#           'size': 1956010157},
#          {'checksum': 'adler32:48949c47,cksum:4030168025',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/89E0B3A3-24F0-4F44-A231-EA2AD97DF5BC.root',
#           'time_create': 1575447016.74132,
#           'size': 1686717109},
#          {'checksum': 'adler32:21588b58,cksum:3765726738',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/70000/DA708F37-AF5B-E844-B8EA-AD99772F30B1.root',
#           'time_create': 1575428802.7185,
#           'size': 1618870108}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#09a6cb8c-a170-4982-8532-975e86a8f2e6',
#         'is_open': 'n',
#         'time_create': 1575420663.68625},
#        {'time_update': 1574250716.05383,
#         'bytes': 5360441057,
#         'files': 4,
#         'file': [{'checksum': 'adler32:f179d118,cksum:779121610',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/9B5B667D-89E1-4643-8BA8-6454B251FD21.root',
#           'time_create': 1574077883.48341,
#           'size': 669467003},
#          {'checksum': 'adler32:4b609963,cksum:1014126656',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/8C0C192C-FD19-A44C-8179-45E3A7EDF6F8.root',
#           'time_create': 1574139956.67523,
#           'size': 1598581663},
#          {'checksum': 'adler32:f0934e46,cksum:3530736334',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/878CC29A-DEB3-3C4D-9278-D0D4FB393E08.root',
#           'time_create': 1574222692.76608,
#           'size': 1557544606},
#          {'checksum': 'adler32:db894ede,cksum:1751987875',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/33629797-1835-8147-92A5-1105FF6F4E82.root',
#           'time_create': 1574107174.80669,
#           'size': 1534847785}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#06f116b1-77e4-47c6-8bd7-b0ca2d16ea57',
#         'is_open': 'n',
#         'time_create': 1574077883.48341},
#        {'time_update': 1574285398.95636,
#         'bytes': 10554132127,
#         'files': 6,
#         'file': [{'checksum': 'adler32:f1137732,cksum:2429385280',
#           'node': 'T2_ES_CIEMAT',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/3B9ACEFE-036E-1C40-A33F-2A7787F41005.root',
#           'time_create': 1574156672.12121,
#           'size': 1803830176},
#          {'checksum': 'adler32:7b8a22de,cksum:486251345',
#           'node': 'T2_ES_CIEMAT',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/A66E803A-0262-2946-B1B5-2E40D37A9E8F.root',
#           'time_create': 1574145133.7731,
#           'size': 1730293826},
#          {'checksum': 'adler32:40fa7049,cksum:3277214785',
#           'node': 'T2_ES_CIEMAT',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/1283E44D-53C3-B442-9607-10EE4E18CAD9.root',
#           'time_create': 1574173042.99071,
#           'size': 1774838311},
#          {'checksum': 'adler32:191994c3,cksum:1698667569',
#           'node': 'T2_ES_CIEMAT',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/7D0D1884-0A66-DD49-80D1-E32FF19D3C1D.root',
#           'time_create': 1574252810.64833,
#           'size': 1683144831},
#          {'checksum': 'adler32:a58543ab,cksum:456527383',
#           'node': 'T2_ES_CIEMAT',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/2FC3A225-CAD6-8846-ACFB-6CD9AA77033E.root',
#           'time_create': 1574112862.18536,
#           'size': 1789757829},
#          {'checksum': 'adler32:27b18a75,cksum:2692139746',
#           'node': 'T2_ES_CIEMAT',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/98E80C64-47EE-1447-917A-B9FE515319D2.root',
#           'time_create': 1574135163.03576,
#           'size': 1772267154}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#36ed4d77-700b-4904-958e-26f0c39bac4a',
#         'is_open': 'n',
#         'time_create': 1574112862.18536},
#        {'time_update': 1574766020.53806,
#         'bytes': 83183202930,
#         'files': 33,
#         'file': [{'checksum': 'adler32:80fc7324,cksum:851124942',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/36A4D7B0-CEE9-F54E-B045-E07D16A08949.root',
#           'time_create': 1574697124.85196,
#           'size': 2970601803},
#          {'checksum': 'adler32:e03a9a8d,cksum:2061616816',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/2EEC3339-F8C8-9444-B618-2889858D8A83.root',
#           'time_create': 1574759296.60262,
#           'size': 2379071960},
#          {'checksum': 'adler32:d73e058c,cksum:456588881',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/3BC1CBEF-406B-274D-B472-3C4C066CC9D2.root',
#           'time_create': 1574683336.72038,
#           'size': 2673189757},
#          {'checksum': 'adler32:25b07090,cksum:3604274731',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/C4C0148A-99E5-234D-819D-08839527F54B.root',
#           'time_create': 1574603222.48641,
#           'size': 1709932541},
#          {'checksum': 'adler32:3796fa21,cksum:1857233475',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/AC4493B2-2078-D54D-AF4E-53A7EA6C2A84.root',
#           'time_create': 1574759554.4035,
#           'size': 2050412916},
#          {'checksum': 'adler32:4aabf96f,cksum:3853148988',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/55688369-2D8A-AD4D-A3ED-BD0A615BA2B4.root',
#           'time_create': 1574739722.37697,
#           'size': 2394071423},
#          {'checksum': 'adler32:0daa7efd,cksum:1726004434',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/F38F3C20-E89C-5741-BFD7-C3DB021CA291.root',
#           'time_create': 1574592913.01736,
#           'size': 1646930567},
#          {'checksum': 'adler32:59c50445,cksum:615825042',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/14BC47AB-08E0-DE45-B2E5-51EB3EE493CC.root',
#           'time_create': 1574751123.40282,
#           'size': 2469615111},
#          {'checksum': 'adler32:06e3574d,cksum:4200365390',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6CE74BB8-30A1-474F-9565-1F0520F3E9E5.root',
#           'time_create': 1574656133.16802,
#           'size': 2997622011},
#          {'checksum': 'adler32:aa47dfc2,cksum:4078346315',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/9C0804A3-4989-7E47-89A2-CDEA4180B8E3.root',
#           'time_create': 1574757707.48512,
#           'size': 2415596163},
#          {'checksum': 'adler32:17bbd932,cksum:4131309472',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/8FA3FC61-1366-9948-986E-397ACE7B9092.root',
#           'time_create': 1574629719.26503,
#           'size': 3140287917},
#          {'checksum': 'adler32:f7e79c3f,cksum:3879130123',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/5F635FF1-5ECD-DD47-BF34-EBFA80CD2104.root',
#           'time_create': 1574708820.31918,
#           'size': 3065096379},
#          {'checksum': 'adler32:0a806537,cksum:4140487175',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/39804E8F-0F72-0D48-8254-A2C244B9D7F1.root',
#           'time_create': 1574720891.5732,
#           'size': 1842333315},
#          {'checksum': 'adler32:5a080ccf,cksum:2413941958',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/CBAAE568-F42E-6142-8225-DF851EF148B5.root',
#           'time_create': 1574764786.76634,
#           'size': 2601116293},
#          {'checksum': 'adler32:eae36560,cksum:1266747092',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/2575826D-91D7-B84F-97D2-E5FE8B2C916F.root',
#           'time_create': 1574761816.31177,
#           'size': 2640011817},
#          {'checksum': 'adler32:b52b573f,cksum:1079282865',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/7763DC83-F517-924C-A0C1-E2541DA5F249.root',
#           'time_create': 1574670968.52362,
#           'size': 2089765093},
#          {'checksum': 'adler32:010d5476,cksum:3019032180',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/43DC052C-7DE8-5341-85FC-6D5CAD246C44.root',
#           'time_create': 1574667624.55724,
#           'size': 1737362836},
#          {'checksum': 'adler32:1fa11ad5,cksum:3224454351',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6067DB05-02DB-C048-856A-D1E056308522.root',
#           'time_create': 1574735338.35883,
#           'size': 2342784747},
#          {'checksum': 'adler32:03d8f91e,cksum:3354210522',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/5D89A83D-3370-A44F-98DE-C01E5208A194.root',
#           'time_create': 1574629719.26503,
#           'size': 2081413099},
#          {'checksum': 'adler32:9b68b1ea,cksum:1451028970',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/2D295A4D-18D7-7C4A-9563-12D979BB8882.root',
#           'time_create': 1574747135.25132,
#           'size': 3079615339},
#          {'checksum': 'adler32:4082e7bb,cksum:3803671057',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/2F328E9A-2A12-2E46-A3A7-404E8753FEEE.root',
#           'time_create': 1574730663.37722,
#           'size': 3104980036},
#          {'checksum': 'adler32:0d09ccb9,cksum:3170250592',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/EDA49EFD-5C9A-1F42-902A-E2424B8F2C51.root',
#           'time_create': 1574647995.13457,
#           'size': 3023103265},
#          {'checksum': 'adler32:8561ac41,cksum:3731279258',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/0A66AFDE-15C2-CC46-A5BB-91828E7395D9.root',
#           'time_create': 1574691067.28325,
#           'size': 3068462418},
#          {'checksum': 'adler32:5b15591d,cksum:1334193045',
#           'node': 'T2_CH_CERN',
# ...
#           'size': 2472529302},
#          {'checksum': 'adler32:89c4be30,cksum:581084065',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/8F037733-72A9-D541-9C4C-3F2C35597ECA.root',
#           'time_create': 1574393084.57048,
#           'size': 1987830305},
#          {'checksum': 'adler32:3f506f69,cksum:473647490',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/A7E46DFB-76DA-7544-84FB-2ABD43BEE058.root',
#           'time_create': 1574377197.34785,
#           'size': 1765422865},
#          {'checksum': 'adler32:4b42b2f3,cksum:2128129292',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/2747613E-3B42-B540-8E00-3BD0EF5EAEFA.root',
#           'time_create': 1574417605.90523,
#           'size': 1764831334},
#          {'checksum': 'adler32:5a760f25,cksum:326848470',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/B6B70047-E902-5F41-8C06-A9DAC7A3362E.root',
#           'time_create': 1574402092.27371,
#           'size': 1709775934},
#          {'checksum': 'adler32:86d95ae6,cksum:875290590',
#           'node': 'T1_RU_JINR_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/C20615B5-587C-304E-8F8F-0F8E499459C5.root',
#           'time_create': 1574386077.05873,
#           'size': 2059210181}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#76026dd4-c537-486a-aa5c-3845a0c7c80a',
#         'is_open': 'n',
#         'time_create': 1574374992.99525},
#        {'time_update': 1574560372.74893,
#         'bytes': 655169699,
#         'files': 1,
#         'file': [{'checksum': 'adler32:d6f88fa5,cksum:2311876499',
#           'node': 'T2_BE_IIHE',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/6EA5F806-FD9A-4547-97B6-D6C06C71FFFB.root',
#           'time_create': 1574387540.36968,
#           'size': 655169699}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#6638f841-530a-4cdb-ae7f-e8b7891dc159',
#         'is_open': 'n',
#         'time_create': 1574387540.36968},
#        {'time_update': 1576193402.33592,
#         'bytes': 2648083091,
#         'files': 2,
#         'file': [{'checksum': 'adler32:cf645fcf,cksum:4129411317',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/260000/6CBE1FB6-A054-3842-A76C-115E4BBD2C4B.root',
#           'time_create': 1576188521.58993,
#           'size': 109260894},
#          {'checksum': 'adler32:bd002ba2,cksum:3992408371',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/260000/8988CEBD-A93A-DB46-A682-EAD7916B149C.root',
#           'time_create': 1576192191.71918,
#           'size': 2538822197}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#8a0fdff7-6616-45d7-b856-635cf10dfbfb',
#         'is_open': 'n',
#         'time_create': 1576188521.58993},
#        {'time_update': 1574589699.65365,
#         'bytes': 45350393726,
#         'files': 18,
#         'file': [{'checksum': 'adler32:fc10151b,cksum:1786570774',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/99DB6F4A-F130-8440-AEB5-34209997676E.root',
#           'time_create': 1574432733.84446,
#           'size': 1504996174},
#          {'checksum': 'adler32:c12cb949,cksum:726402103',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/65182F9B-E255-444F-BB5D-670490D0F710.root',
#           'time_create': 1574497250.37958,
#           'size': 2314380691},
#          {'checksum': 'adler32:c7cfc10f,cksum:2402876548',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/BA8853C6-CF18-974B-A0C0-995CF714E3B0.root',
#           'time_create': 1574538263.10736,
#           'size': 1877898412},
#          {'checksum': 'adler32:45867259,cksum:1639522636',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/EEFA01CB-B0EB-7548-8C83-62DB8B48D238.root',
#           'time_create': 1574518398.7141,
#           'size': 2685863771},
#          {'checksum': 'adler32:881df6e2,cksum:1654324913',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/0DD5CE8B-A604-E348-99A4-4A0906105667.root',
#           'time_create': 1574583843.64539,
#           'size': 3069850747},
#          {'checksum': 'adler32:8d04a943,cksum:2960611867',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/A67AEE3A-F93B-EC4F-8983-5654BDD8E809.root',
#           'time_create': 1574567612.05388,
#           'size': 3061285025},
#          {'checksum': 'adler32:af67add0,cksum:2903270739',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/469DA522-409D-7C4D-A9A9-ABD3918692F6.root',
#           'time_create': 1574565321.08552,
#           'size': 1768118682},
#          {'checksum': 'adler32:c9dfa691,cksum:3813105153',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/BF45C679-1CF6-AB42-B468-2E2A2D554BF5.root',
#           'time_create': 1574508861.87325,
#           'size': 1692041965},
#          {'checksum': 'adler32:368dde92,cksum:3152673499',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/C95B40E7-551E-CD4C-A91B-8673FD61534C.root',
#           'time_create': 1574456293.53389,
#           'size': 3081849410},
#          {'checksum': 'adler32:6fae27bb,cksum:1874242512',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/EDE5BADB-CB8C-E44E-83CA-3C2137B6056F.root',
#           'time_create': 1574469474.91281,
#           'size': 3107293409},
#          {'checksum': 'adler32:af180938,cksum:4213041541',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6677BBC6-6BEE-6241-A9EA-056800BA3A04.root',
#           'time_create': 1574476092.42372,
#           'size': 2230491961},
#          {'checksum': 'adler32:4ffd6d75,cksum:3708821946',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/CBCA50B8-6F18-7547-91F8-6A99B195FBBC.root',
#           'time_create': 1574553149.51326,
#           'size': 2962383029},
#          {'checksum': 'adler32:c76072f8,cksum:4102810062',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/998A165A-C47B-7145-BD27-536C1FAD4B48.root',
#           'time_create': 1574545611.91222,
#           'size': 3139002849},
#          {'checksum': 'adler32:914331c7,cksum:4129439047',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/39C70519-FFF8-8548-BE90-0969DD8E7173.root',
#           'time_create': 1574572308.5679,
#           'size': 2146243189},
#          {'checksum': 'adler32:1bd61d86,cksum:3049156536',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/64231D73-0287-194F-99F7-6F67B7F3387E.root',
#           'time_create': 1574416873.41577,
#           'size': 2938418763},
#          {'checksum': 'adler32:01090389,cksum:1651344885',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/0965E441-49E9-E74B-95DA-33B23F922D39.root',
#           'time_create': 1574534399.40014,
#           'size': 1698950699},
#          {'checksum': 'adler32:c25c207d,cksum:2395999053',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/9EAD23D0-866E-854E-8C2D-56B91BF19CEE.root',
#           'time_create': 1574445985.58788,
#           'size': 3080535654},
#          {'checksum': 'adler32:fdb099d3,cksum:3573683481',
#           'node': 'T2_CH_CERN',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/77FDB844-FCFD-9641-AEBD-D48D040B4E37.root',
#           'time_create': 1574432733.84446,
#           'size': 2990789296}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#7f18a85a-e981-44ee-9e45-9701d899c2f6',
#         'is_open': 'n',
#         'time_create': 1574416873.41577},
#        {'time_update': 1574942269.19698,
#         'bytes': 36218963,
#         'files': 1,
#         'file': [{'checksum': 'adler32:cb9ff4f5,cksum:3232662719',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/0B74745B-8904-5549-B6B7-8847D1A64BA6.root',
#           'time_create': 1574769524.33025,
#           'size': 36218963}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#8b9cc40f-0fa8-41b9-9bc3-6270400ff491',
#         'is_open': 'n',
#         'time_create': 1574769524.33025},
#        {'time_update': 1575291123.8092,
#         'bytes': 90550567,
#         'files': 1,
#         'file': [{'checksum': 'adler32:4e6e161a,cksum:3403517833',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/EEF4DB00-6594-3941-8717-3B54697F2E55.root',
#           'time_create': 1575168838.46029,
#           'size': 90550567}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#b6ed3aa8-f1b4-47f0-b24e-6a85962a49f7',
#         'is_open': 'n',
#         'time_create': 1575168838.46029},
#        {'time_update': 1575291086.12637,
#         'bytes': 714602481,
#         'files': 1,
#         'file': [{'checksum': 'adler32:03368025,cksum:1798297889',
#           'node': 'T2_IT_Bari',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/EC64D866-9D22-FE43-95AB-8E0423BD6415.root',
#           'time_create': 1575128017.92557,
#           'size': 714602481}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#58f14eb8-48af-4da3-a95b-d3b3bce662bb',
#         'is_open': 'n',
#         'time_create': 1575128017.92557},
#        {'time_update': 1574256612.60944,
#         'bytes': 3529161180,
#         'files': 3,
#         'file': [{'checksum': 'adler32:48dd8cea,cksum:3744454509',
#           'node': 'T2_IT_Bari',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/BE683598-BE35-D649-8B8B-B543604CB8E1.root',
#           'time_create': 1574083800.88606,
#           'size': 249581299},
#          {'checksum': 'adler32:06db8b0e,cksum:290625299',
#           'node': 'T2_IT_Bari',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/D73A848E-F64C-DC4C-9686-4E97EC672031.root',
#           'time_create': 1574247217.06978,
#           'size': 1686819346},
#          {'checksum': 'adler32:85e0b81f,cksum:2858714238',
#           'node': 'T2_IT_Bari',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/FC23384E-0EB4-AA42-A448-AC9272D34EBF.root',
#           'time_create': 1574217763.00544,
#           'size': 1592760535}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#30df6ef0-171b-4fe1-bfe1-8ff382db8d2c',
#         'is_open': 'n',
#         'time_create': 1574083800.88606},
#        {'time_update': 1574756624.92514,
#         'bytes': 18634833749,
#         'files': 12,
#         'file': [{'checksum': 'adler32:c6bc2109,cksum:972591769',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/6802F8B1-26F1-A248-8C8B-40A437E9DC58.root',
#           'time_create': 1574753850.3197,
#           'size': 198829836},
#          {'checksum': 'adler32:0c8c68bd,cksum:3933465502',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/9275A916-F25E-0040-B55F-4948811AB5C8.root',
#           'time_create': 1574673614.71202,
#           'size': 1775074289},
#          {'checksum': 'adler32:09dc3f82,cksum:1591200853',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/B879BE72-8CD2-A744-9FAE-3B635BA24335.root',
#           'time_create': 1574678763.39988,
#           'size': 1614484478},
#          {'checksum': 'adler32:87fa05fb,cksum:2275109245',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/50E14315-17AE-A040-BB38-DEE6DC51CDF9.root',
#           'time_create': 1574645887.25284,
#           'size': 1663043287},
#          {'checksum': 'adler32:e13d7d26,cksum:3689756495',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/890008AC-7709-2E43-B4B4-7C2762EBE3E6.root',
#           'time_create': 1574584126.57768,
#           'size': 1802280732},
#          {'checksum': 'adler32:1f9e8e29,cksum:3785576672',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/30036948-F29F-E34C-B361-4C1149A385A6.root',
#           'time_create': 1574746332.01401,
#           'size': 503524214},
#          {'checksum': 'adler32:45ec425d,cksum:2319430798',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/3D8610B3-80B3-A74C-B325-663E8D1EF5F4.root',
#           'time_create': 1574667849.90554,
#           'size': 1787365057},
#          {'checksum': 'adler32:b048ad7a,cksum:2579975629',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/12CFF90E-D944-FD4F-BC1D-4FA608FD8A4F.root',
#           'time_create': 1574656146.25246,
#           'size': 1795011354},
#          {'checksum': 'adler32:dba8c7b8,cksum:4232881920',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/54EB872C-80C4-0E4C-9F57-28D41B1BAB23.root',
#           'time_create': 1574632472.37965,
#           'size': 1881687126},
#          {'checksum': 'adler32:8a1bd427,cksum:4294360641',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/C88E08AC-63CD-9940-8C18-C63B5B52A7AA.root',
#           'time_create': 1574657175.61467,
#           'size': 1800784548},
#          {'checksum': 'adler32:f7c98d51,cksum:3807650252',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/7EA76A5B-5878-0E4A-AF04-918A52E64DBA.root',
#           'time_create': 1574619909.7559,
#           'size': 1855002748},
#          {'checksum': 'adler32:3b70368d,cksum:2767044387',
#           'node': 'T1_US_FNAL_Disk',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/270000/B47BC242-8955-C245-A3EF-C10DB9899CD9.root',
#           'time_create': 1574607896.38419,
#           'size': 1957746080}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#ad517d0e-0104-4dbe-8a4a-6a597c240e63',
#         'is_open': 'n',
#         'time_create': 1574584126.57768},
#        {'time_update': 1574670061.12025,
#         'bytes': 36075060,
#         'files': 1,
#         'file': [{'checksum': 'adler32:810d27a5,cksum:952920345',
#           'node': 'T2_FR_GRIF_IRFU',
#           'lfn': '/store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL2018-v2/100000/52E4DDA5-37BC-BC4C-BACB-025DFED930E7.root',
#           'time_create': 1574497039.99778,
#           'size': 36075060}],
#         'name': '/EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#c8166c72-fe5f-4930-bb9e-c607866d30d6',
#         'is_open': 'n',
#         'time_create': 1574497039.99778}],
#       'time_create': 1573886727.38397}],
#     'name': 'https://cmsweb.cern.ch/dbs/prod/global/DBSReader',
#     'time_create': 1177442550}],
#   'instance': 'prod',
#   'request_url': 'http://cmsweb.cern.ch:7001/phedex/datasvc/json/prod/data',
#   'request_version': '2.5.0pre3-comp',
#   'request_call': 'data',
#   'call_time': 0.08323,
#   'request_date': '2020-03-18 20:34:40 UTC'}}

# %%
#json = [
    {
        'some': 'nested',
        'data': [
            {'key': 'val1'},
            {'key': 'val2'},
            {'key': 'val3'},
        ]
    },
    {
        'some': 'more',
        'data': [
            {'key': 'val4'},
            {'key': 'val5'},
            {'key': 'val6'},
        ]
    },
]
out = []
for toplevel in json:
    for secondlevel in toplevel['data']:
        out.append({
            'some': toplevel['some'],
            'key': secondlevel['key'],
        })
print(out)
# Out:
#   File "<ipython-input-155-8ae5c0c0030b>", line 2
#     {
#     ^
# IndentationError: unexpected indent

# %%
out = []
for _instance in data['phedex']['dbs']:
    for _dataset in _instance['dataset']:
        for _block in _dataset['block']:
            for _file in _block['file']:
                out.append({
                'Dataset': _dataset['name'],
                'Is dataset open': _dataset['is_open'],
                'block Name': _block['name'],
                'Block size (GB)': _block['bytes']/1000000000.0,
                'Time block was created': _block['time_create'],
                'File name': _file['lfn'],
                'File checksum': _file['checksum'],
                'File size':  _file['size'],
                'Time file was created': _file['time_create']
                })

# %%
df=json_normalize(out)
format_dates(df, ["Time file was created",'Time block was created'])
# Out:
#                                         Dataset Is dataset open  \
# 0    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 1    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 2    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 3    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 4    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# ..                                          ...             ...
# 768  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 769  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 770  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 771  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
# 772  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO               y
#
#                                             block Name  Block size (GB)  \
# 0    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#2f9...         2.353711
# 1    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#2f9...         2.353711
# 2    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#2f9...         2.353711
# 3    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#eb8...         1.812333
# 4    /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#eb8...         1.812333
# ..                                                 ...              ...
# 768  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#ad5...        18.634834
# 769  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#ad5...        18.634834
# 770  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#ad5...        18.634834
# 771  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#ad5...        18.634834
# 772  /EGamma/Run2018A-12Nov2019_UL2018-v2/DQMIO#c81...         0.036075
#
#            Time block was created  \
# 0   2019-11-17 21:08:27.658509970
# 1   2019-11-17 21:08:27.658509970
# 2   2019-11-17 21:08:27.658509970
# 3   2019-11-18 20:54:18.046839952
# 4   2019-11-18 20:54:18.046839952
# ..                            ...
# 768 2019-11-24 08:28:46.577680111
# 769 2019-11-24 08:28:46.577680111
# 770 2019-11-24 08:28:46.577680111
# 771 2019-11-24 08:28:46.577680111
# 772 2019-11-23 08:17:19.997780085
#
#                                              File name  \
# 0    /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 1    /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 2    /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 3    /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 4    /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# ..                                                 ...
# 768  /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 769  /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 770  /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 771  /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
# 772  /store/data/Run2018A/EGamma/DQMIO/12Nov2019_UL...
#
#                          File checksum   File size  \
# 0     adler32:84458e13,cksum:843148796   569420538
# 1    adler32:d290b9c8,cksum:4293630207  1406279668
# 2    adler32:b4fddac3,cksum:4218643856   378010767
# 3    adler32:d273d7ef,cksum:2120672845  1440351579
# 4    adler32:e92fd24e,cksum:1545795842   313277819
# ..                                 ...         ...
# 768  adler32:dba8c7b8,cksum:4232881920  1881687126
# 769  adler32:8a1bd427,cksum:4294360641  1800784548
# 770  adler32:f7c98d51,cksum:3807650252  1855002748
# 771  adler32:3b70368d,cksum:2767044387  1957746080
# 772   adler32:810d27a5,cksum:952920345    36075060
#
#             Time file was created
# 0   2019-11-17 21:08:27.658509970
# 1   2019-11-19 20:57:54.007920027
# 2   2019-11-18 20:59:33.452300072
# 3   2019-11-18 20:54:18.046839952
# 4   2019-11-19 16:44:42.158459902
# ..                            ...
# 768 2019-11-24 21:54:32.379650116
# 769 2019-11-25 04:46:15.614670038
# 770 2019-11-24 18:25:09.755899906
# 771 2019-11-24 15:04:56.384190083
# 772 2019-11-23 08:17:19.997780085
#
# [773 rows x 9 columns]
